# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')
sns.set_style('darkgrid')
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)

N = 4
ind = np.arange(N)  # the x locations for the groups
width = 0.2     # the width of the bars

fig = plt.figure()
ax = fig.add_subplot(111)


#a = np.array([0, 2.69, 25.86, 34.03])
#b = np.array([1.6, 15.9, 29.2, 40.93])
#c = np.array([3.72, 12.87, 31.26, 31.74])
#d = np.array([7.52, 17.71, 41.35, 38.23])

'''
a = np.array([36.35, 64.94, 58.09, 26.32])
b = np.array([59.93, 59.19, 54.27, 26.26])
c = np.array([20.41, 53.66, 45.67, 31.51])
d = np.array([27.76, 20.21, 38.65, 30.5])
'''

a = np.array([3.68, 7.78, 32.51, 29.97])
b = np.array([5.23, 20.81, 25.03, 24.02])
c = np.array([61.03, 7.37, 8.4, 9.64])
d = np.array([24.23, 76.61, 64.3, 33.12])


'''
yvals = [200, 198.1, 161.7, 91.8]
rects1 = ax.bar(ind, yvals, width, color='silver', yerr=a/2)
zvals = [198.87, 187.1, 166.97, 74.73]
rects2 = ax.bar(ind+width, zvals, width, color='y', yerr=b/2)
kvals = [197.36, 190.9, 156.03, 75.77]
rects3 = ax.bar(ind+width*2, kvals, width, color='m', yerr=c/2)#
lvals = [193.53, 180.63, 127.77, 70.23]
rects4 = ax.bar(ind+width*3, lvals, width, color='c', yerr=d/2)

yvals = [174.3, 147.83, 116.5, 50.7]
rects1 = ax.bar(ind, yvals, width, color='silver', yerr=a/2)
zvals = [154.63, 98.63, 81.6, 47.2]
rects2 = ax.bar(ind+width, zvals, width, color='y', yerr=b/2)
kvals = [183.87, 151.87, 112.37, 72.17]
rects3 = ax.bar(ind+width*2, kvals, width, color='m', yerr=c/2)
lvals = [171.03, 143.93, 110.37, 75.17]
rects4 = ax.bar(ind+width*3, lvals, width, color='c', yerr=d/2)
'''

yvals = [197.4, 194.5, 165.63, 68.3]
rects1 = ax.bar(ind, yvals, width, color='silver', yerr=a/2)
zvals = [196.3, 171.43, 118.83, 64]
rects2 = ax.bar(ind+width, zvals, width, color='y', yerr=b/2)
kvals = [143.97, 30.03, 29.53, 24.73]
rects3 = ax.bar(ind+width*2, kvals, width, color='m', yerr=c/2)
lvals = [182.87, 128.57, 94.43, 52.93]
rects4 = ax.bar(ind+width*3, lvals, width, color='c', yerr=d/2)


ax.set_ylabel('Mean Reward')
ax.set_xlabel('Noise Levels')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('0', '0.25', '0.5', '1') )
ax.legend( (rects1[0], rects2[0], rects3[0], rects4[0]), ('0,0', '0.5,0', '0,0.5', '0.25,0.25'), loc='center left', bbox_to_anchor=(1, 0.5) )




def autolabel(rects):
    for rect in rects:
        h = rect.get_height()
#        ax.text(rect.get_x()+rect.get_width()/2., 1.05*h, '%d'%int(h),
#                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)


plt.rcParams['figure.figsize'] = (10.0, 10.0) # set figure_size
plt.show()
