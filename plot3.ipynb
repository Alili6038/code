# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
sns.set_context('talk')

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %%
y_means = np.random.rand(50) * 0.5
y_stds = np.random.rand(50) * 0.2
xs = np.arange(50)

plt.plot(xs, y_means)
plt.fill_between(xs, y_means-y_stds/2, y_means+y_stds/2, alpha=0.3)

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)

names = range(0,30)
names = [str(x) for x in list(names)]

x = range(len(names))


#[0.840,0.839,0.834,0.832,0.824,0.831,0.823,0.817,0.814,0.812,0.812,0.807,0.805]


#[0.838,0.840,0.840,0.834,0.828,0.814,0.812,0.822,0.818,0.815,0.807,0.801,0.796]

'''
y_RS_noise_0 = np.array([  9.43333333, 172.06666667, 182.16666667, 180.43333333,
                           179.16666667, 188.33333333, 183.63333333, 191.5       ,
                           185.36666667, 189.8       , 186.6       , 188.43333333,
                           187.83333333, 196.53333333, 193.06666667, 198.83333333,
                           195.96666667, 194.2       , 194.93333333, 199.5       ,
                           200.        , 200.        , 200.        , 200.        ,
                           200.        , 200.        , 200.        , 200.        ,
                           200.        , 200.        ])

y_RS_noise_025 = np.array([  9.43333333,  94.43333333, 101.2       ,  79.03333333,
                             97.63333333,  86.7       ,  85.43333333,  86.56666667,
                             93.73333333, 104.93333333, 106.63333333, 102.03333333,
                             113.06666667, 104.16666667, 110.        , 111.4       ,
                             110.3       , 127.06666667, 128.53333333, 128.56666667,
                             130.26666667, 143.7       , 156.93333333, 151.26666667,
                             146.1       , 157.6       , 163.96666667, 165.73333333,
                             179.33333333, 174.76666667])



y_RS_noise_05 = np.array([ 9.46666667, 50.46666667, 75.7       , 70.7       , 76.1       ,
                           70.96666667, 63.4       , 69.53333333, 70.63333333, 72.26666667,
                           71.83333333, 75.6       , 78.93333333, 90.16666667, 83.1       ,
                           88.6       , 73.93333333, 85.93333333, 80.3       , 81.46666667,
                           83.26666667, 80.46666667, 97.23333333, 82.63333333, 95.13333333,
                           92.93333333, 75.13333333, 99.63333333, 97.53333333, 96.1       ])

y_RS_noise_1 = np.array([ 9.4       , 60.96666667, 57.53333333, 66.4       , 55.13333333,
                          58.13333333, 51.26666667, 50.86666667, 53.1       , 60.16666667,
                          52.53333333, 53.03333333, 60.33333333, 50.13333333, 54.23333333,
                          51.93333333, 62.16666667, 62.3       , 59.23333333, 56.9       ,
                          53.26666667, 58.83333333, 65.2       , 56.23333333, 52.73333333,
                          55.43333333, 65.26666667, 51.56666667, 54.76666667, 54.13333333])



y_CEM_noise_0 = np.array([  9.23333333, 108.23333333, 113.36666667, 126.03333333,
                            135.1       , 131.7       , 150.56666667, 143.26666667,
                            151.1       , 138.06666667, 176.16666667, 174.96666667,
                            156.36666667, 171.        , 164.96666667, 176.96666667,
                            166.13333333, 174.93333333, 176.23333333, 182.13333333,
                            173.06666667, 167.56666667, 175.43333333, 176.93333333,
                            184.96666667, 171.06666667, 174.86666667, 169.66666667,
                            176.16666667, 170.63333333])

y_CEM_noise_025 = np.array([  9.16666667,  55.86666667,  96.2       , 103.83333333,
                              115.43333333, 138.1       , 140.96666667, 137.26666667,
                              155.43333333, 148.8       , 148.73333333, 153.3       ,
                              162.16666667, 152.73333333, 160.8       , 151.96666667,
                               4.98658422e+01, 3.95946405e+01, 4.48032985e+01, 4.61695426e+01,
                               3.47172388e+01, 3.59930858e+01, 4.46588053e+01, 4.25210013e+01,
                               4.68683973e+01, 4.78119464e+01, 3.37665515e+01, 3.41488246e+01,
                               4.44096836e+01, 3.18133096e+01])
y_CEM_noise_1_std = np.array([ 0.04714045,  7.39909904, 11.43445087, 16.06009548,  7.49058669,
                               7.49177327, 20.86160748, 13.77848564, 17.39738167, 11.45697265,
                               23.5208182 , 14.66659091, 14.29848477, 15.90618328, 19.29185205,
                               13.04326135, 21.82969435, 15.45236408, 13.61184125, 16.14132034,
                               11.29286894, 16.69737172, 16.07074637, 15.99187294, 20.0257057 ,
                               13.94090703, 14.21040308, 21.08654126, 15.05929023,  9.76057831])
'''
y_GA_noise_0_std = np.array([2.06733860e+01, 8.34780211e+01, 7.68430869e+01, 5.37401154e+01,
                             0.00000000e+00, 1.19736748e+01, 6.97678691e+00, 9.42809042e-02,
                             0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
                             0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.49844396e+00,
                             0.00000000e+00, 8.98025983e+01, 0.00000000e+00, 0.00000000e+00,
                             0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.14551299e+01,
                             0.00000000e+00, 4.71404521e-02, 0.00000000e+00, 0.00000000e+00,
                             2.89442376e+01, 5.18544973e-01])
y_GA_noise_025_std = np.array([16.36507121, 41.6257399 , 31.95688067, 23.31794731, 26.5853761 ,
                               12.73062798, 39.99077671, 45.72791513, 14.11531871,  2.61661359,
                               7.09945225, 13.15218613, 18.35774133,  7.87584211, 77.75535709,
                               4.07785347, 18.54747662,  0.        ,  4.4312025 ,  2.68700577,
                               0.        ,  0.        ,  2.59272486,  1.36707311,  3.48839345,
                               1.79133718,  6.71532245, 13.38788839,  0.        ,  2.02703944])
y_GA_noise_05_std = np.array([25.60559835, 18.27973985, 31.51902424, 18.85777175, 35.96575532,
                              17.63689315, 20.83122656, 53.12252086, 22.24924468, 19.71040334,
                              25.8584609 , 11.38254024, 24.01513412, 22.83914768, 32.81229444,
                              6.86164865,  5.79827561,  9.64238329, 80.34236464,  6.85127725,
                              81.59069936, 78.07470781,  7.16720928, 77.59385715,  2.61916017,
                              13.31423632, 33.77892176,  4.90260702, 12.240915  , 11.15078473])
y_GA_noise_1_std = np.array([11.65113252, 15.52832537,  7.17960073, 11.53959368, 21.20571202,
                             2.08219969, 19.17608464,  8.34918492, 12.86761655, 19.13675928,
                             12.06067991, 17.3482628 ,  6.49153295, 16.72609405, 17.51386752,
                             7.83170196,  6.71830005, 15.31585961, 11.18699642, 44.10966133,
                             48.0030786 , 33.71590459, 57.49179652, 31.34840063, 38.47908523,
                             17.31749276, 44.38485728, 31.19433709,  5.34186817, 24.61927881])



#plt.plot(x, y_RS_noise_0, marker='o', mec='r', mfc='w',label='RS_noise_0')
#plt.plot(x, y_RS_noise_025, marker='*', ms=10,label='RS_noise_025')
#plt.plot(x, y_RS_noise_05, marker='^', ms=10,label='RS_noise_05')
#plt.plot(x, y_RS_noise_1, marker='v', ms=10,label='RS_noise_1')
'''
plt.plot(x, y_RS_noise_0, marker='o', linestyle='-', color='blue',label='RS_noise_0')
plt.plot(x, y_RS_noise_025, marker='*', linestyle='--', color='blue',label='RS_noise_025')
plt.plot(x, y_RS_noise_05, marker='^', linestyle='-.', color='blue',label='RS_noise_05')
plt.plot(x, y_RS_noise_1, marker='s', linestyle=':', color='blue',label='RS_noise_1')

plt.plot(x, y_CEM_noise_0, marker='o', linestyle='-', color='olive',label='CEM_noise_0')
plt.plot(x, y_CEM_noise_025, marker='*', linestyle='--', color='olive',label='CEM_noise_025')
plt.plot(x, y_CEM_noise_05, marker='^', linestyle='-.', color='olive',label='CEM_noise_05')
plt.plot(x, y_CEM_noise_1, marker='s', linestyle=':', color='olive',label='CEM_noise_1')
'''
plt.plot(x, y_GA_noise_0, marker='o', linestyle='-', color='darkred',label='GA_noise_0')
plt.plot(x, y_GA_noise_025, marker='*', linestyle='--', color='darkred',label='GA_noise_025')
plt.plot(x, y_GA_noise_05, marker='^', linestyle='-.', color='darkred',label='GA_noise_05')
plt.plot(x, y_GA_noise_1, marker='s', linestyle=':', color='darkred',label='GA_noise_1')

'''
plt.fill_between(x, y_RS_noise_0-y_RS_noise_0_std/2, y_RS_noise_0+y_RS_noise_0_std/2, alpha=0.3)
plt.fill_between(x, y_RS_noise_025-y_RS_noise_025_std/2, y_RS_noise_025+y_RS_noise_025_std/2, alpha=0.3)
plt.fill_between(x, y_RS_noise_05-y_RS_noise_05_std/2, y_RS_noise_05+y_RS_noise_05_std/2, alpha=0.3)
plt.fill_between(x, y_RS_noise_1-y_RS_noise_1_std/2, y_RS_noise_1+y_RS_noise_1_std/2, alpha=0.3)

plt.fill_between(x, y_CEM_noise_0-y_CEM_noise_0_std/2, y_CEM_noise_0+y_CEM_noise_0_std/2, alpha=0.3)
plt.fill_between(x, y_CEM_noise_025-y_CEM_noise_025_std/2, y_CEM_noise_025+y_CEM_noise_025_std/2, alpha=0.3)
plt.fill_between(x, y_CEM_noise_05-y_CEM_noise_05_std/2, y_CEM_noise_05+y_CEM_noise_05_std/2, alpha=0.3)
plt.fill_between(x, y_CEM_noise_1-y_CEM_noise_1_std/2, y_CEM_noise_1+y_CEM_noise_1_std/2, alpha=0.3)
'''
plt.fill_between(x, y_GA_noise_0-y_GA_noise_0_std/2, y_GA_noise_0+y_GA_noise_0_std/2, alpha=0.3)
plt.fill_between(x, y_GA_noise_025-y_GA_noise_025_std/2, y_GA_noise_025+y_GA_noise_025_std/2, alpha=0.3)
plt.fill_between(x, y_GA_noise_05-y_GA_noise_05_std/2, y_GA_noise_05+y_GA_noise_05_std/2, alpha=0.3)
plt.fill_between(x, y_GA_noise_1-y_GA_noise_1_std/2, y_GA_noise_1+y_GA_noise_1_std/2, alpha=0.3)


plt.legend()  # 让图例生效plt.xticks(x, names, rotation=1)
#plt.xticks(x, names, rotation=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))


#plt.margins(0)
#plt.subplots_adjust(bottom=0.10)
plt.xlabel('Training Iteration') #X轴标签
plt.ylabel('Rewards') #Y轴标签
#plt.yticks([0.750,0.800,0.850])
#plt.title("A simple plot") #标题
# Out:
# Text(0, 0.5, 'Rewards')
